# %% [markdown]
# # 1. Importing Libraries

# %%
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import layers, models

import matplotlib.pyplot as plt
import seaborn as sns

import warnings

warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
## initializing basic needed params

## Image size
IMAGE_SIZE = 150 

## batch size 
BATCH_SIZE = 32

## Channel size
CHANELS = 3

## Epochs
EPOCHS = 100

# %% [markdown]
# # 2. Loading Dataset

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "Intel Image Dataset",
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 3000 files belonging to 6 classes.

# %%
labels = dataset.class_names
print(f"label names :- {labels}\ntotal labels {len(labels)}\nlength of dataset:- {len(dataset)}")
# Out:
# label names :- ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']
# total labels 6
# length of dataset:- 94

# %%
# 94*32 = 3008 ~ 3000

# %% [markdown]
# ### Visualizing Data

# %%
plt.figure(figsize=(15,5))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        plt.subplot(2,6,i+1)
        plt.imshow(image_batch[i].numpy().astype('uint8'))
        plt.title(labels[label_batch[i].numpy()])
        plt.axis("off")

# %% [markdown]
# # 3. Spliting dataset

# %%
len(dataset)
# Out:
# 94

# %%
## training = 80%
# 10% validation, 10% testing

# %%
# training data
train_size = 0.8
train_size = len(dataset)* train_size
print(f"Training size :- {train_size}")


# validation data
val_size = 0.1
val_size = len(dataset) * val_size
print(f"validation size :- {val_size}")


# Testing data
test_ds = 0.1
test_ds = len(dataset) * test_ds
print(f"Testing size :- {test_ds}")
# Out:
# Training size :- 75.2
# validation size :- 9.4
# Testing size :- 9.4

# %%
train_split = 0.8
test_split = 0.1
val_split  = 0.1


ds_len = len(dataset)

train_size = int(ds_len * train_split)
val_size = int(ds_len * val_split)

train_ds = dataset.take(train_size)


val_ds = dataset.skip(train_size).take(val_size) # validation data should not include trainig data
test_ds = dataset.skip(train_size).skip(val_size)  # test data should not include testing as well as validation data

print(f"Training data size:- {train_size}\nlenght {len(train_ds)}\n")
print(f"Validation data size:- {val_size}\nlenght {len(val_ds)}\n")
print(f"Testing data\nlenght {len(test_ds)}")
# Out:
# Training data size:- 75
# lenght 75
#
# Validation data size:- 9
# lenght 9
#
# Testing data
# lenght 10

# %%
def train_test_split_tf(ds, train_split = 0.8, val_split = 0.1, test_split=0.1, shuffle=True, shuffle_size = 10000):
    
    ds_len = len(dataset)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)


    train_size = int(ds_len * train_split)
    val_size = int(ds_len * val_split)

    train_ds = ds.take(train_size) # it includs 80 % data 


    val_ds = ds.skip(train_size).take(val_size) # validation data should not include trainig data
    test_ds = ds.skip(train_size).skip(val_size)  # test data should not include testing as well as validation data
    
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = train_test_split_tf(dataset)

# %%
print(f"training_data_size : {len(train_ds)}\nvalidation_data_size : {len(val_ds)}\ntesting_data_size : {len(test_ds)}")
# Out:
# training_data_size : 75
# validation_data_size : 9
# testing_data_size : 10

# %%
# This way we are optimizing our model

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)

# %% [markdown]
# # 4. Preprocessing

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Rescaling(IMAGE_SIZE, IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %% [markdown]
# # 5. Data Agumentation
# ###### This is a tuning technique which is use to create more similar pics in order to avoid overfitting in the model

# %%
data_agumentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip(mode='horizontal_and_vertical'),
    layers.experimental.preprocessing.RandomRotation(0.3)
])

# %% [markdown]
# # 5. Model Building

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANELS)
n_classes = 6

model = models.Sequential([
    resize_and_rescale,
    data_agumentation,
    layers.Conv2D(filters=32,kernel_size=(3,3), padding="same", activation="relu",input_shape=input_shape),  
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(filters=64,kernel_size=(3,3), padding="same", activation="relu"),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(filters=64,kernel_size=(3,3), padding="same", activation="relu"),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(filters=64,kernel_size=(3,3), padding="same",  activation="relu"),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(filters=64,kernel_size=(3,3), padding="same",  activation="relu"),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(filters=64,kernel_size=(3,3), padding="same", activation="relu"),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Flatten(),
    layers.Dense(units=64, activation="relu"),
    layers.Dense(units=n_classes, activation='softmax')
])

model.build(input_shape=input_shape )

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 150, 150, 3)         0
#
#  sequential_1 (Sequential)   (32, 150, 150, 3)         0
#
#  conv2d (Conv2D)             (32, 150, 150, 32)        896
#
#  max_pooling2d (MaxPooling2D  (32, 75, 75, 32)         0
#  )
#
#  conv2d_1 (Conv2D)           (32, 75, 75, 64)          18496
#
#  max_pooling2d_1 (MaxPooling  (32, 37, 37, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (32, 37, 37, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (32, 18, 18, 64)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (32, 18, 18, 64)          36928
#
#  max_pooling2d_3 (MaxPooling  (32, 9, 9, 64)           0
#  2D)
#
#  conv2d_4 (Conv2D)           (32, 9, 9, 64)            36928
#
#  max_pooling2d_4 (MaxPooling  (32, 4, 4, 64)           0
#  2D)
#
#  conv2d_5 (Conv2D)           (32, 4, 4, 64)            36928
#
#  max_pooling2d_5 (MaxPooling  (32, 2, 2, 64)           0
#  2D)
#
#  flatten (Flatten)           (32, 256)                 0
#
#  dense (Dense)               (32, 64)                  16448
#
#  dense_1 (Dense)             (32, 6)                   390
#
# =================================================================
# Total params: 183,942
# Trainable params: 183,942
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer="adam",
    loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=["accuracy"]
)

# %%
history = model.fit(
    train_ds, 
    epochs=EPOCHS,
    verbose=1,
    validation_data=val_ds
)
# Out:
# Epoch 1/100
# 75/75 [==============================] - 41s 474ms/step - loss: 1.6975 - accuracy: 0.3265 - val_loss: 1.4937 - val_accuracy: 0.3507
# Epoch 2/100
# 75/75 [==============================] - 34s 456ms/step - loss: 1.3326 - accuracy: 0.4574 - val_loss: 1.5369 - val_accuracy: 0.3438
# Epoch 3/100
# 75/75 [==============================] - 34s 458ms/step - loss: 1.2511 - accuracy: 0.4887 - val_loss: 1.4984 - val_accuracy: 0.4062
# Epoch 4/100
# 75/75 [==============================] - 33s 441ms/step - loss: 1.2166 - accuracy: 0.5092 - val_loss: 1.3290 - val_accuracy: 0.4514
# Epoch 5/100
# 75/75 [==============================] - 34s 451ms/step - loss: 1.1755 - accuracy: 0.5422 - val_loss: 1.6577 - val_accuracy: 0.4271
# Epoch 6/100
# 75/75 [==============================] - 35s 461ms/step - loss: 1.1519 - accuracy: 0.5573 - val_loss: 1.1913 - val_accuracy: 0.5278
# Epoch 7/100
# 75/75 [==============================] - 34s 451ms/step - loss: 1.1392 - accuracy: 0.5485 - val_loss: 1.2154 - val_accuracy: 0.5382
# Epoch 8/100
# 75/75 [==============================] - 33s 446ms/step - loss: 1.0872 - accuracy: 0.5844 - val_loss: 1.2444 - val_accuracy: 0.4965
# Epoch 9/100
# 75/75 [==============================] - 34s 452ms/step - loss: 1.0566 - accuracy: 0.5890 - val_loss: 1.1336 - val_accuracy: 0.5556
# Epoch 10/100
# 75/75 [==============================] - 34s 451ms/step - loss: 1.0470 - accuracy: 0.5999 - val_loss: 1.3456 - val_accuracy: 0.4965
# Epoch 11/100
# 75/75 [==============================] - 33s 446ms/step - loss: 1.0201 - accuracy: 0.6221 - val_loss: 1.2093 - val_accuracy: 0.5208
# Epoch 12/100
# 75/75 [==============================] - 34s 449ms/step - loss: 1.0096 - accuracy: 0.6183 - val_loss: 1.1446 - val_accuracy: 0.5694
# Epoch 13/100
# 75/75 [==============================] - 35s 461ms/step - loss: 1.0044 - accuracy: 0.6237 - val_loss: 1.1838 - val_accuracy: 0.5764
# Epoch 14/100
# 75/75 [==============================] - 33s 437ms/step - loss: 1.0054 - accuracy: 0.6242 - val_loss: 1.1480 - val_accuracy: 0.5556
# Epoch 15/100
# 75/75 [==============================] - 33s 446ms/step - loss: 1.0005 - accuracy: 0.6258 - val_loss: 1.2314 - val_accuracy: 0.5521
# Epoch 16/100
# 75/75 [==============================] - 33s 444ms/step - loss: 0.9589 - accuracy: 0.6359 - val_loss: 1.3857 - val_accuracy: 0.5694
# Epoch 17/100
# 75/75 [==============================] - 33s 441ms/step - loss: 0.9447 - accuracy: 0.6480 - val_loss: 1.1576 - val_accuracy: 0.5451
# Epoch 18/100
