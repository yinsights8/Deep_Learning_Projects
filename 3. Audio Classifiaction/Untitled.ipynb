# %%
# !pip install librosa

# !pip install --user --upgrade matplotlib

# %%
# !pip install scipy

# %%
# !pip install matplotlib

# %%
import librosa
librosa.__version__
# Out:
# '0.10.0.post2'

# %%
## import libraries

# this is library which is use to prerprocess the audio data and also nommalize the data
import librosa
import librosa.display

## this is the library which is use to display the audio data
import IPython.display as ipd

# scipy.io is also the library which with the help we can prepross the audio data but it dosen't normalize the data
from scipy.io import wavfile as wav
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\yashd\AppData\Local\Temp\ipykernel_14992\1699537367.py", line 5, in <module>
#     import librosa.display
#   File "C:\Users\yashd\anaconda3\lib\site-packages\librosa\display.py", line 90, in <module>
#     class TimeFormatter(mplticker.Formatter):
#   File "C:\Users\yashd\anaconda3\lib\importlib\util.py", line 245, in __getattribute__
#     self.__spec__.loader.exec_module(self)
#   File "C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
# ImportError: DLL load failed while importing _path: The specified module could not be found.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ImportError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\yashd\anaconda3\lib\inspect.py", line 1543, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\yashd\anaconda3\lib\inspect.py", line 1501, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\yashd\anaconda3\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\yashd\anaconda3\lib\inspect.py", line 746, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\yashd\anaconda3\lib\importlib\util.py", line 245, in __getattribute__
#     self.__spec__.loader.exec_module(self)
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\cm.py", line 25, in <module>
#     from matplotlib import _api, colors, cbook, scale
#   File "C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
# ImportError: cannot import name 'NullFormatter' from 'matplotlib.ticker' (C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\ticker.py)
# Traceback (most recent call last):
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\yashd\AppData\Local\Temp\ipykernel_14992\1699537367.py", line 5, in <module>
#     import librosa.display
#   File "C:\Users\yashd\anaconda3\lib\site-packages\librosa\display.py", line 90, in <module>
#     class TimeFormatter(mplticker.Formatter):
#   File "C:\Users\yashd\anaconda3\lib\importlib\util.py", line 245, in __getattribute__
#     self.__spec__.loader.exec_module(self)
#   File "C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
# ImportError: DLL load failed while importing _path: The specified module could not be found.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ImportError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2079, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\yashd\anaconda3\lib\inspect.py", line 1543, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\yashd\anaconda3\lib\inspect.py", line 1501, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\yashd\anaconda3\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\yashd\anaconda3\lib\inspect.py", line 746, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\yashd\anaconda3\lib\importlib\util.py", line 245, in __getattribute__
#     self.__spec__.loader.exec_module(self)
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\axes\__init__.py", line 1, in <module>
#     from . import _base
#   File "C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 14, in <module>
#     from matplotlib import _api, cbook, _docstring, offsetbox
#   File "C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\offsetbox.py", line 31, in <module>
#     import matplotlib.artist as martist
#   File "C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\artist.py", line 15, in <module>
#     from .colors import BoundaryNorm
#   File "C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
# ImportError: cannot import name 'NullFormatter' from 'matplotlib.ticker' (C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\ticker.py)
# Traceback (most recent call last):
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\yashd\AppData\Local\Temp\ipykernel_14992\1699537367.py", line 5, in <module>
#     import librosa.display
#   File "C:\Users\yashd\anaconda3\lib\site-packages\librosa\display.py", line 90, in <module>
#     class TimeFormatter(mplticker.Formatter):
#   File "C:\Users\yashd\anaconda3\lib\importlib\util.py", line 245, in __getattribute__
#     self.__spec__.loader.exec_module(self)
#   File "C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
# ImportError: DLL load failed while importing _path: The specified module could not be found.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ImportError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2079, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2079, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\yashd\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\yashd\anaconda3\lib\inspect.py", line 1543, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\yashd\anaconda3\lib\inspect.py", line 1501, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\yashd\anaconda3\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\yashd\anaconda3\lib\inspect.py", line 746, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\yashd\anaconda3\lib\importlib\util.py", line 245, in __getattribute__
#     self.__spec__.loader.exec_module(self)
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\pyplot.py", line 52, in <module>
#     import matplotlib.colorbar
#   File "C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\colorbar.py", line 19, in <module>
#     from matplotlib import _api, cbook, collections, cm, colors, contour, ticker
#   File "C:\Users\yashd\anaconda3\lib\site-packages\matplotlib\collections.py", line 19, in <module>
#     from . import (_api, _path, artist, cbook, cm, colors as mcolors, _docstring,
# ImportError: DLL load failed while importing _path: The specified module could not be found.

# %%
# visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### reading the audio file

# %%
filepath = "free-spoken-digit-dataset-master/recordings/0_george_0.wav"

# %%
# !dir

# %%
# loading a file with the help of librosa
data, sample_rate = librosa.load(filepath)
print(sample_rate)

# loading a file with the help of scipy
# wav_sample_rate, wav_data = wav
# print(wav_sample_rate)

# %%
## visualizing the audio
plt.figure(figsize=(10,5))
librosa.display.waveshow(data, sr=sample_rate)
ipd.Audio(filepath)
